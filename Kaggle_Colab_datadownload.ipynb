# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cd to folder in which data should be available

# %%
cd 'drive/My Drive/AIMLDataScience/Projects/Capstone/PneumoniaDetection/Data'
# Out:
# /content/drive/My Drive/AIMLDataScience/Projects/Capstone/PneumoniaDetection/Data

# %% [markdown]
# From kaggle profile download kaggle.json file to get user name and token needed below

# %%
#Configuration environment
import os

os.environ['KAGGLE_USERNAME'] = "abcd" # username from the json file
os.environ['KAGGLE_KEY'] = "4bc5894532f334df486c7135cce3b887" # key from the json file

# %% [markdown]
# From kaggle get the api for required data set and use it in below format: !<datasetapi>

# %%
# !kaggle competitions download -c rsna-pneumonia-detection-challenge
